# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
def list2dict(ls):
    dic = dict()
    for term in ls:
        if term not in dic:
            dic[term] = 1
        else:
            dic[term] += 1
    return dic

def data_formating(raw_df):
    df = raw_df
    df['Phrase'] = df.Phrase.apply(lambda s: s.lower())
    #df = raw_df.assign(PhraseSplit=raw_df.Phrase.apply(lambda s: list2dict(str.split(s, " "))))
    df = raw_df.assign(PhraseSplit=raw_df.Phrase.apply(lambda s: str.split(str(s), " ")))
    df = df.assign(WordTotal=df.PhraseSplit.apply(lambda l: len(l)), Length=data.Phrase.apply(len))
    idx_empty = df[df.Phrase==" "].index[0]
    df = df.drop(idx_empty)
    return df

def rvwhitespace(s):
    if s=='' or s==' ' :
        return ''
    if s[0]==' ':
        i=1
    else:
        i=0
    if s[-1]==' ':
        return s[i:-1]
    else:
        return s[i:]

# %%
data = pd.read_csv("train.tsv", sep="\t")
data = data_formating(data).reset_index().drop('index', 1).sort_values('WordTotal').reset_index().drop(['index','SentenceId'], axis=1)

# %%
NV = max(data[data.WordTotal==1].index)
d = 10
P = tf.Variable(tf.random_normal([d, NV]))
Ws = tf.Variable(tf.random_normal([5, d]))
W  = tf.Variable(tf.random_normal([d, 2*d]))

index_rec = np.loadtxt("index_rec.txt", dtype=np.int32)
entry_rec = np.loadtxt("entry_rec.txt", dtype=np.int32)

index_tf = tf.constant(index_rec, dtype=tf.int32)
entry_tf = tf.constant(entry_rec, dtype=tf.int32)

def selectfromSoftmax(p):
    return tf.nn.softmax(tf.transpose(tf.matmul(Ws, p)))

def p_accumulate(p, x):
    p_next = tf.transpose([tf.gather( tf.transpose(P), x)])
    return tf.nn.tanh( tf.matmul( W, tf.concat(0, [p, p_next] ) )  )

def prob(idx):
    subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
    p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]), lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
    #p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]))
    return p

def prob_seq(p, seq):
    p_next = prob(seq)
    return tf.nn.tanh( tf.matmul( W, tf.concat(0, [p, p_next] ) )  )

def selectfromSoftmax(p):
    return tf.nn.softmax(tf.transpose(tf.matmul(Ws, p)))

def single_cost(idx, sentiment):
    softmax = selectfromSoftmax( prob(idx) )
    return - tf.log( softmax[0, sentiment] )

subidx = entry_tf[index_tf[0,41362]:index_tf[0,41362]+index_tf[1,41362]]
l = tf.constant(2)

# %%
index_rec = np.loadtxt("index_rec.txt", dtype=np.int32)
entry_rec = np.loadtxt("entry_rec.txt", dtype=np.int32)

# %%
init = tf.initialize_all_variables()
sess = tf.Session()
sess.run(init)
#sess.run( tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#sess.run( tf.shape(tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0]) )
sess.run(subidx[0])
# Out:
# 16258

# %%
sess.run( tf.cond(tf.less(subidx[0], NV), lambda: tf.transpose([tf.gather( tf.transpose(P), 41362)]), lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0]) )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-83c436bcf9ed> in <module>()
# ----> 1 sess.run( tf.cond(tf.less(subidx[0], NV), lambda: tf.transpose([tf.gather( tf.transpose(P), 41362)]), lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0]) )
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-9-83c436bcf9ed> in <lambda>()
# ----> 1 sess.run( tf.cond(tf.less(subidx[0], NV), lambda: tf.transpose([tf.gather( tf.transpose(P), 41362)]), lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0]) )
#
# <ipython-input-4-ba4958d7ec57> in prob(idx)
#      20 def prob(idx):
#      21     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
# ---> 22     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]), lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      23     #p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]))
#      24     return p
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-4-ba4958d7ec57> in <lambda>()
#      20 def prob(idx):
#      21     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
# ---> 22     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]), lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      23     #p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]))
#      24     return p
#
# ... last 4 frames repeated, from the frame below ...
#
# <ipython-input-4-ba4958d7ec57> in prob(idx)
#      20 def prob(idx):
#      21     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
# ---> 22     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]), lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      23     #p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]))
#      24     return p
#
# RuntimeError: maximum recursion depth exceeded

# %%
#sess.close()
init = tf.initialize_all_variables()
sess = tf.Session()

sess.run(init)
#sess.run( tf.transpose([tf.gather( tf.transpose(P), tf.constant(20))]) )
#sess.run( tf.cond( tf.less(20, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), 20)]), lambda: tf.transpose([tf.gather( tf.transpose(P), 20)]) ) )
sess.run(prob(20))
# Out:
# 20
# array([[-1.00855839],
#        [-0.26731169],
#        [-0.49827424],
#        [ 0.04112599],
#        [-0.58034861],
#        [ 0.15101646],
#        [ 1.91307449],
#        [-0.15683414],
#        [-1.65405548],
#        [-1.64405346]], dtype=float32)

# %%
sess.run(prob(subidx[0]))
# Out:
# Tensor("strided_slice_8:0", dtype=int32)
# Tensor("cond_2/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond_2/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/cond/strided_slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond__slice_1:0", dtype=int32)
# Tensor("cond_..._slice_1:0", dtype=int32)
# Tensor("cond_..._slice_1:0", dtype=int32)
# Tensor("cond_..._slice_1:0", dtype=int32)
# Tensor("cond_..._slice_1:0", dtype=int32)
# Tensor("cond_..._slice_1:0", dtype=int32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-f14cc1f1341a> in <module>()
# ----> 1 sess.run(prob(subidx[0]))
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
# ...
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in cond(pred, fn1, fn2, name)
#    1715     context_f = CondContext(pred, pivot_2, branch=0)
#    1716     context_f.Enter()
# -> 1717     _, res_f = context_f.BuildCondBranch(fn2)
#    1718     context_f.ExitResult(res_f)
#    1719     context_f.Exit()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in BuildCondBranch(self, fn)
#    1611   def BuildCondBranch(self, fn):
#    1612     """Add the subgraph defined by fn() to the graph."""
# -> 1613     r = fn()
#    1614     original_r = r
#    1615     result = []
#
# <ipython-input-10-64f9f08bb11c> in <lambda>()
#      22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
# ---> 24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#      25     return p
#      26
#
# <ipython-input-10-64f9f08bb11c> in prob(idx)
#      20 def prob(idx):
#      21     print(idx)
# ---> 22     subidx = entry_tf[index_tf[0,idx]:index_tf[0,idx]+index_tf[1,idx]]
#      23     p = tf.cond( tf.less(idx, NV), lambda: tf.transpose([tf.gather( tf.transpose(P), idx)]),
#      24                         lambda: tf.scan(prob_seq, subidx[1:], initializer=prob(subidx[0]))[0] )
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/array_ops.pyc in _SliceHelper(tensor, slice_spec, var)
#     381         ellipsis_mask=ellipsis_mask,
#     382         var=var,
# --> 383         name=name)
#     384
#     385
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/array_ops.pyc in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#     535       ellipsis_mask=ellipsis_mask,
#     536       new_axis_mask=new_axis_mask,
# --> 537       shrink_axis_mask=shrink_axis_mask)
#     538
#     539   def assign(val):
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/gen_array_ops.pyc in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#    2748                                 ellipsis_mask=ellipsis_mask,
#    2749                                 new_axis_mask=new_axis_mask,
# -> 2750                                 shrink_axis_mask=shrink_axis_mask, name=name)
#    2751   return result
#    2752
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.pyc in apply_op(self, op_type_name, name, **keywords)
#     747           op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     748                            input_types=input_types, attrs=attr_protos,
# --> 749                            op_def=op_def)
#     750           outputs = op.outputs
#     751           return _Restructure(ops.convert_n_to_tensor(outputs),
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2378     ret = Operation(node_def, self, inputs=inputs, output_types=dtypes,
#    2379                     control_inputs=control_inputs, input_types=input_types,
# -> 2380                     original_op=self._default_original_op, op_def=op_def)
#    2381     if compute_shapes:
#    2382       set_shapes_for_outputs(ret)
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1300     self._control_flow_context = g._get_control_flow_context()
#    1301     if self._control_flow_context is not None:
# -> 1302       self._control_flow_context.AddOp(self)
#    1303     # NOTE(keveman): Control flow context's AddOp could be creating new ops and
#    1304     # setting op.inputs[index] = new_op. Thus the new ops' id could be larger
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in AddOp(self, op)
#    1574
#    1575   def AddOp(self, op):
# -> 1576     self._AddOpInternal(op)
#    1577
#    1578   def _AddOpInternal(self, op):
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in _AddOpInternal(self, op)
#    1599             real_x = self._outer_context.AddValue(x)
#    1600             self._values.add(real_x.name)
# -> 1601           real_x = _SwitchRefOrTensor(real_x, self._pred)[self._branch]
#    1602           self._external_values[x.name] = real_x
#    1603         x = self._external_values.get(x.name)
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in _SwitchRefOrTensor(data, pred, name)
#     374       if data.dtype.is_ref_dtype:
#     375         return ref_switch(data, pred, name=name)
# --> 376     return switch(data, pred, name=name)
#     377
#     378
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/control_flow_ops.pyc in switch(data, pred, dtype, name)
#     309     pred = ops.convert_to_tensor(pred, name="pred")
#     310     if isinstance(data, ops.Tensor):
# --> 311       return gen_control_flow_ops._switch(data, pred, name=name)
#     312     else:
#     313       if not isinstance(data, (ops.IndexedSlices, ops.SparseTensor)):
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/gen_control_flow_ops.pyc in _switch(data, pred, name)
#     364     output_true: A `Tensor`. Has the same type as `data`. If `pred` is true, data will be forwarded to this output.
#     365   """
# --> 366   result = _op_def_lib.apply_op("Switch", data=data, pred=pred, name=name)
#     367   return _SwitchOutput._make(result)
#     368
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.pyc in apply_op(self, op_type_name, name, **keywords)
#     747           op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     748                            input_types=input_types, attrs=attr_protos,
# --> 749                            op_def=op_def)
#     750           outputs = op.outputs
#     751           return _Restructure(ops.convert_n_to_tensor(outputs),
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2378     ret = Operation(node_def, self, inputs=inputs, output_types=dtypes,
#    2379                     control_inputs=control_inputs, input_types=input_types,
# -> 2380                     original_op=self._default_original_op, op_def=op_def)
#    2381     if compute_shapes:
#    2382       set_shapes_for_outputs(ret)
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1296     self._original_op = original_op
#    1297     self._op_def = op_def
# -> 1298     self._traceback = _extract_stack()
#    1299     # Add this op to the current control flow context:
#    1300     self._control_flow_context = g._get_control_flow_context()
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _extract_stack()
#     117     frame_globals = f.f_globals
#     118     ret.append((filename, lineno, name, frame_globals))
# --> 119     f = f.f_back
#     120   ret.reverse()
#     121   return ret
#
# KeyboardInterrupt:
